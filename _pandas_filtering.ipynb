# %%
import pandas as pd

df = pd.read_csv('laptop.csv')

# %%
df[df['price'] > 60000]
# Out:
#       Unnamed: 0                                         model_name    brand  \
# 6              6                     Infinix Zero Book Ultra Laptop  Infinix
# 10            10   Asus Vivobook Pro 15 OLED M6500QH-HN701WS Laptop     Asus
# 11            11              Apple MacBook Air 2020 MGND3HN Laptop    Apple
# 20            20                      Apple MacBook Air 2022 Laptop    Apple
# 27            27                       HP Victus 15-fa0165TX Laptop       HP
# ...          ...                                                ...      ...
# 1005        1009                     HP Pavilion 14-EC1008AU Laptop       HP
# 1007        1011        Asus Strix G15 G513RM-HQ273WS Gaming Laptop     Asus
# 1009        1013                     Fujitsu UH-X 4ZR1F38024 Laptop  Fujitsu
# 1011        1015             Lenovo Yoga 6 13ALC6 82ND00DPIN Laptop   Lenovo
# 1013        1017  Asus ROG Strix Scar 17 G733ZW-LL139WS Gaming L...     Asus
#
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
df[df['screen_sizeinches'] > 15]
# Out:
#       unnamed:_0                                         model_name   brand  \
# 0              0                Lenovo V15 ITL G2 82KBA033IH Laptop  Lenovo
# 1              1              HP Pavilion 15-ec2004AX Gaming Laptop      HP
# 2              2                       Lenovo V15 82KBA03HIH Laptop  Lenovo
# 3              3      Asus Vivobook 16X 2022 M1603QA-MB502WS Laptop    Asus
# 4              4                             HP 15s-fr4000TU Laptop      HP
# ...          ...                                                ...     ...
# 999         1003                 HP Victus 16-e0361ax Gaming Laptop      HP
# 1002        1006           Asus TUF A15 OLED FA507RM-HF030WS Laptop    Asus
# 1006        1010                             HP 15s-du3519TX Laptop      HP
# 1007        1011        Asus Strix G15 G513RM-HQ273WS Gaming Laptop    Asus
# 1013        1017  Asus ROG Strix Scar 17 G733ZW-LL139WS Gaming L...    Asus
#
# ...

# %%
df.query("operating_system == 'Windows' and ramgb <= 8 and ~processor_name.str.contains('Intel', na=False) and screen_sizeinches <= 15",engine='python')
# Out:
#       unnamed:_0                                  model_name   brand  \
# 18            18                     Realme Book Slim Laptop  Realme
# 21            21      Asus VivoBook 14 X415JA-BV301WS Laptop    Asus
# 25            25             Lenovo E41-55 82FJ00AGIH Laptop  Lenovo
# 33            33                    HP 245 G8 62G68PA Laptop      HP
# 34            34                   Acer One 14 Z2-493 Laptop    Acer
# ...          ...                                         ...     ...
# 1003        1007      Asus VivoBook 14 X415JA-EB501WS Laptop    Asus
# 1004        1008  Asus VivoBook 14 2021 X415MA-BV011W Laptop    Asus
# 1008        1012             Asus BR1100CKA-GJ0722W Notebook    Asus
# 1010        1014               Asus BR1100CKA-GJ0722W Laptop    Asus
# 1012        1016               Asus BR1100FKA-BP1104W Laptop    Asus
#
#           processor_name  ramgb  ssdgb  hard_diskgb operating_system  \
# ...

# %%
df[(df['operating_system'].isin(['Windows', 'Linux'])) & (df['ramgb'] >= 8) & (df['processor_name'].str.contains('Intel', na=False)) & (df['screen_sizeinches'].between(13, 17)) & (df['price'].between(40000, 80000))
]
# Out:
#      unnamed:_0                                      model_name brand  \
# 716         720  Acer Nitro AN515-57 UN.QEHSI.003 Gaming Laptop  Acer
#
#     processor_name  ramgb  ssdgb  hard_diskgb operating_system  \
# 716  Intel Core i5     16    512            0          Windows
#
#                          graphics  screen_sizeinches resolution_pixels  \
# 716  4 GB NVIDIA GeForce GTX 1650               15.6       1920 x 1080
#
#      no_of_cores  no_of_threads  spec_score  price
# 716            6             12          67  62990

# %%
df[(df['operating_system'].isin(['Windows', 'Linux'])) & (df['processor_name'].str.contains('AMD', na=False)) & (df['no_of_threads'] >= 6) & (df['screen_sizeinches'] > 14) &
    (df['screen_sizeinches'] < 17) & (df['price'] > 50000) &
    (df['price'] < 100000)
]
# Out:
#      unnamed:_0                                         model_name   brand  \
# 1             1              HP Pavilion 15-ec2004AX Gaming Laptop      HP
# 17           17                HP Victus 15-fb0040AX Gaming Laptop      HP
# 47           48          Lenovo IdeaPad Gaming 3 82K201YAIN Laptop  Lenovo
# 50           52          Lenovo IdeaPad Gaming 3 82K201UEIN Laptop  Lenovo
# 52           54        Asus TUF Gaming A15 FA506IHRZ-HN111W Laptop    Asus
# 53           55                HP Victus 15-fb0050AX Gaming Laptop      HP
# 85           89          Lenovo IdeaPad Gaming 3 82K201Y9IN Laptop  Lenovo
# 89           93  Asus TUF Gaming A15 2022 FA577RE-HN055WS Gamin...    Asus
# 213         217  Asus Vivobook Pro 15 OLED M3500QC-L1461WS Gami...    Asus
# 216         220  Asus TUF Gaming A15 2022 FA506QM-HN008W Gaming...    Asus
# 272         276                 HP Victus 16-e0650AX Gaming Laptop      HP
# ...
